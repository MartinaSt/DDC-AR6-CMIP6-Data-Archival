# %% [markdown]
# # Find datasets which never were in ESGF
#
# Either the given PID or the PID reconstructed by the DRS *must* have been registered in the PID-handle service as this cannot be bypassed when publishing the data. For all entires in the TSU list:
#
# - if no PID is given, we create the PID via the hash function: `'21.14100/'+str(uuid.uuid3(uuid.NAMESPACE_URL, DRS))'`
#     - for the constructed PID, we check if there is a record. If not, the TSU entry was never in ESGF
# - if a PID is given, we check if there is a record. If not, the TSU entry was never in ESGF

# %%
import json
import pandas as pd
import tqdm
import uuid
with open("cmip6_list_2022-07-11.json") as f:
    cmip6_list=json.load(f)

# %%
cmip6_requested_drs_list_idx=[]
cmip6_requested_drs_list=[]
cmip6_requested_pids_list=[]
for dset in cmip6_list[0]:
    cmip6_requested_drs_list_idx.append(tuple(dset["data_ref_syntax"].split('.')[1:]))
    cmip6_requested_drs_list.append('.'.join(dset["data_ref_syntax"].split('.')[1:]))
    cmip6_requested_pids_list.append(dset["tracking_id_nc"])

# %%
len(cmip6_requested_pids_list)
# Out:
# 18909

# %%
from pyhandle.handleclient import PyHandleClient
client = PyHandleClient('rest')

# %%
pids_not_solvable={}
pids_no_url_orig_data={}
pids_not_available=[]
created_pids={}
drs_wrong=[]
new_drs={}
li=0
for pids,drs in tqdm.tqdm(zip(cmip6_requested_pids_list, cmip6_requested_drs_list),total=len(cmip6_requested_drs_list)):
    check_drs='CMIP6.'+drs
    pid_drs='CMIP6.'+'.'.join(drs.split('.')[:-1])+".v"+drs.split('.')[-1]
        #if check_drs not in cmip6_notinpool_notinesgf :
        #continue
    if not pids :
        pids_not_available.append(drs)
        uuid_ds = str(uuid.uuid3(uuid.NAMESPACE_URL, pid_drs))
        pids = ['21.14100/'+uuid_ds ]
        if not client.retrieve_handle_record(pids[0]):
            drs_wrong.append(pid_drs)
            continue
        else:
            created_pids[drs]=pids[0]
#        continue
    else:
        if not client.retrieve_handle_record(pids[0]):
            pids_not_solvable[drs]=pids[0]        
            continue
    try:
        url_orig_data=client.retrieve_handle_record(pids[0])["URL_ORIGINAL_DATA"]
        if check_drs in cmip6_notinpool_notinesgf:
            pid_drs='.'.join(url_orig_data.split('CMIP6')[1].split('/')[1:9])+'.'+url_orig_data.split('CMIP6')[1].split('/')[9].split('v')[1]
            print(pid_drs)
            if pid_drs != check_drs:
                new_drs[drs]=pid_drs
    except:
        pids_no_url_orig_data[drs]=pids[0]
# Out:
# 100%|██████████| 18909/18909 [1:21:40<00:00,  3.86it/s]

# %%
drs_wrong=['.'.join(k.split('.')[0:-1])+'.'+k.split('.')[-1].split('v')[1] for k in drs_wrong]

# %%
drs_wrong
# Out:
# ['CMIP6.ScenarioMIP.CAS.FGOALS-g3.ssp245.r1i1p1f1.day.tas.gn.20190818-20190819',
#  'CMIP6.CMIP.CAS.FGOALS-f3-L.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.CAS.FGOALS-f3-L.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.CAS.FGOALS-f3-L.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CAS.FGOALS-g3.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.CAS.FGOALS-g3.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r10i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r11i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r12i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r13i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r14i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r15i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r16i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r17i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r18i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r19i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r20i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r21i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r22i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r23i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r24i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r25i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r2i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r3i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r4i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r5i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r6i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r7i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r8i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r9i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CMCC.CMCC-CM2-SR5.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.CMCC.CMCC-CM2-SR5.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.CMCC.CMCC-CM2-SR5.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.r1i1p1f1.Omon.volcello.gn.',
#  'CMIP6.CMIP.CSIRO.ACCESS-ESM1-5.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.CSIRO.ACCESS-ESM1-5.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CSIRO.ACCESS-ESM1-5.historical.r1i1p1f1.Omon.volcello.gn.',
#  'CMIP6.CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r1i1p1f3.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r1i1p1f3.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r2i1p1f3.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r2i1p1f3.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r3i1p1f3.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r3i1p1f3.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r4i1p1f3.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical.r4i1p1f3.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r10i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r10i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r11i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r11i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r12i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r12i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r16i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r16i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r17i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r17i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r18i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r18i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r19i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r19i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r2i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r2i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r3i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r3i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r4i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r4i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r5i1p1f3.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r5i1p1f3.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r6i1p1f3.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r6i1p1f3.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r7i1p1f3.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r7i1p1f3.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r8i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r8i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r9i1p1f2.Omon.thetao.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r9i1p1f2.Omon.volcello.gn.',
#  'CMIP6.CMIP.MPI-M.MPI-ESM1-2-HR.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.MPI-M.MPI-ESM1-2-HR.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.MPI-M.MPI-ESM1-2-HR.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.MPI-M.MPI-ESM1-2-LR.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.MPI-M.MPI-ESM1-2-LR.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.MPI-M.MPI-ESM1-2-LR.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-FV2.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-FV2.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-FV2.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM-FV2.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM-FV2.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM-FV2.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r10i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r11i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r2i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r3i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r4i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r5i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r6i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r7i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r8i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NCAR.CESM2.historical.r9i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-ESM4.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-ESM4.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-ESM4.historical.r1i1p1f1.Omon.volcello.gn.',
#  'CMIP6.CMIP.THU.CIESM.historical.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.THU.CIESM.historical.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.CMIP.THU.CIESM.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r10i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r2i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r3i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r4i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r5i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r6i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r7i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r8i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r9i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CSIRO.ACCESS-ESM1-5.hist-nat.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.DAMIP.CSIRO.ACCESS-ESM1-5.hist-nat.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.CSIRO.ACCESS-ESM1-5.hist-nat.r3i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r1i1p1f3.Omon.thetao.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r1i1p1f3.Omon.thkcello.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r2i1p1f3.Omon.thetao.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r2i1p1f3.Omon.thkcello.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r3i1p1f3.Omon.thetao.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r3i1p1f3.Omon.thkcello.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r4i1p1f3.Omon.thetao.gn.',
#  'CMIP6.DAMIP.MOHC.HadGEM3-GC31-LL.hist-nat.r4i1p1f3.Omon.thkcello.gn.',
#  'CMIP6.DAMIP.NCAR.CESM2.hist-nat.r1i1p1f1.Ofx.volcello.gn.',
#  'CMIP6.DAMIP.NCAR.CESM2.hist-nat.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.NCAR.CESM2.hist-nat.r2i1p1f1.Omon.thetao.gn.',
#  'CMIP6.DAMIP.NCAR.CESM2.hist-nat.r3i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CDRMIP.CCCma.CanESM5.1pctCO2-cdr.r1i1p2f1.SImon.zostoga.gn.20190429',
#  'CMIP6.CDRMIP.CSIRO.ACCESS-ESM1-5.1pctCO2-cdr.r1i1p1f1.Omon.zostoga.gn.20191214',
#  'CMIP6.CDRMIP.MIROC.MIROC-ES2L.1pctCO2-cdr.r1i1p1f2.Omon.zostoga.gn.20200622',
#  'CMIP6.CDRMIP.MOHC.UKESM1-0-LL.1pctCO2-cdr.r1i1p1f2.Omon.zostoga.gm.20200425',
#  'CMIP6.CDRMIP.NCAR.CESM2.1pctCO2-cdr.r1i1p1f1.Omon.zostoga.gn.20190613',
#  'CMIP6.CMIP.AS-RCEC.TaiESM1.historical.r1i1p1f1.Amon.pr.gn.20200608',
#  'CMIP6.CMIP.AS-RCEC.TaiESM1.historical.r1i1p1f1.Amon.ua.gn.20200608',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp126.r1i1p1f1.Amon.pr.gn.20201110',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp126.r1i1p1f1.Amon.ua.gn.20201110',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp245.r1i1p1f1.Amon.pr.gn.20201014',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp245.r1i1p1f1.Amon.ua.gn.20201014',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp370.r1i1p1f1.Amon.pr.gn.20201012',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp370.r1i1p1f1.Amon.ua.gn.20201012',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp585.r1i1p1f1.Amon.pr.gn.20200826',
#  'CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp585.r1i1p1f1.Amon.ua.gn.20200826',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp126.r1i1p1f1.Amon.pr.gn.20190930',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp126.r1i1p1f1.Amon.pr.gn.20191002',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp126.r1i1p1f1.Amon.ua.gn.20190728',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp126.r1i1p1f1.Amon.ua.gn.20190729',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp126.r1i1p1f1.Amon.ua.gn.20190730',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.pr.gn.20190930',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.pr.gn.20191002',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.ua.gn.20190609',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.ua.gn.20190610',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.ua.gn.20190726',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.ua.gn.20190729',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.ua.gn.20190730',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.ua.gn.20190731',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.r1i1p1f1.Amon.pr.gn.20190927',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.r1i1p1f1.Amon.pr.gn.20191002',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.r1i1p1f1.Amon.ua.gn.20190603',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.r1i1p1f1.Amon.ua.gn.20190711',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.r1i1p1f1.Amon.ua.gn.20190712',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.r1i1p1f1.Amon.ua.gn.20190715',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.r1i1p1f1.Amon.ua.gn.20190719',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.pr.gn.20190930',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.pr.gn.20191002',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.ua.gn.20190609',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.ua.gn.20190610',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.ua.gn.20190726',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.ua.gn.20190728',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.ua.gn.20190729',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.ua.gn.20190730',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp119.r1i1p1f1.Amon.pr.gn.20190701',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp119.r1i1p1f1.Amon.ua.gn.20190702',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp126.r1i1p1f1.Amon.pr.gn.20190627',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp126.r1i1p1f1.Amon.ua.gn.20190702',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp245.r1i1p1f1.Amon.pr.gn.20190627',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp245.r1i1p1f1.Amon.ua.gn.20190702',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp370.r1i1p1f1.Amon.pr.gn.20190627',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp370.r1i1p1f1.Amon.ua.gn.20190702',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp585.r1i1p1f1.Amon.pr.gn.20190627',
#  'CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp585.r1i1p1f1.Amon.ua.gn.20190702',
#  'CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp126.r1i1p1f1.Amon.pr.gn.20201024',
#  'CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp126.r1i1p1f1.Amon.ua.gn.20201024',
#  'CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp245.r1i1p1f1.Amon.pr.gn.20200814',
#  'CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp245.r1i1p1f1.Amon.ua.gn.20200814',
#  'CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp585.r1i1p1f1.Amon.pr.gn.20200921',
#  'CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp585.r1i1p1f1.Amon.ua.gn.20200921',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp126.r1i1p1f1.Amon.pr.gn.20200622',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp126.r1i1p1f1.Amon.ua.gn.20200622',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp245.r1i1p1f1.Amon.pr.gn.20200615',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp245.r1i1p1f1.Amon.ua.gn.20200615',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp370.r1i1p1f1.Amon.pr.gn.20200618',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp370.r1i1p1f1.Amon.ua.gn.20200618',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp585.r1i1p1f1.Amon.pr.gn.20200616',
#  'CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp585.r1i1p1f1.Amon.ua.gn.20200616',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp126.r1i1p1f2.Amon.pr.gr.20191104',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp126.r1i1p1f2.Amon.ua.gr.20191104',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp126.r1i1p1f2.Amon.ua.gr.20191124',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp245.r1i1p1f2.Amon.pr.gr.20191015',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp245.r1i1p1f2.Amon.ua.gr.20191015',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp245.r1i1p1f2.Amon.ua.gr.20191102',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp370.r1i1p1f2.Amon.pr.gr.20191104',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp370.r1i1p1f2.Amon.ua.gr.20191104',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp370.r1i1p1f2.Amon.ua.gr.20191123',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp585.r1i1p1f2.Amon.pr.gr.20190913',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp585.r1i1p1f2.Amon.ua.gr.20190913',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp585.r1i1p1f2.Amon.ua.gr.20191016',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp126.r1i1p1f2.Amon.pr.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp126.r1i1p1f2.Amon.ua.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.r1i1p1f2.Amon.pr.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245.r1i1p1f2.Amon.ua.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.r1i1p1f2.Amon.pr.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp370.r1i1p1f2.Amon.ua.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp585.r1i1p1f2.Amon.pr.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp585.r1i1p1f2.Amon.ua.gr.20181115',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp119.r1i1p1f2.Amon.pr.gr.20181201',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp119.r1i1p1f2.Amon.ua.gr.20181201',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp126.r1i1p1f2.Amon.pr.gr.20180816',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp126.r1i1p1f2.Amon.ua.gr.20180816',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp245.r1i1p1f2.Amon.pr.gr.20180816',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp245.r1i1p1f2.Amon.ua.gr.20180816',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp370.r1i1p1f2.Amon.pr.gr.20180816',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp370.r1i1p1f2.Amon.ua.gr.20180816',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp585.r1i1p1f2.Amon.pr.gr.20180816',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp585.r1i1p1f2.Amon.ua.gr.20180816',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126.r1i1p1f1.Amon.pr.gn.20190720',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126.r1i1p1f1.Amon.pr.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126.r1i1p1f1.Amon.pr.gn.20190723',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126.r1i1p1f1.Amon.ua.gn.20190720',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126.r1i1p1f1.Amon.ua.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126.r1i1p1f1.Amon.ua.gn.20190723',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.pr.gn.20190715',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.pr.gn.20190717',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.pr.gn.20190718',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.pr.gn.20190719',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.pr.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.ua.gn.20190715',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.ua.gn.20190717',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.ua.gn.20190718',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.ua.gn.20190719',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245.r1i1p1f1.Amon.ua.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp370.r1i1p1f1.Amon.pr.gn.20190720',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp370.r1i1p1f1.Amon.pr.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp370.r1i1p1f1.Amon.ua.gn.20190720',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp370.r1i1p1f1.Amon.ua.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585.r1i1p1f1.Amon.pr.gn.20190721',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585.r1i1p1f1.Amon.pr.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585.r1i1p1f1.Amon.pr.gn.20190723',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585.r1i1p1f1.Amon.ua.gn.20190721',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585.r1i1p1f1.Amon.ua.gn.20190722',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585.r1i1p1f1.Amon.ua.gn.20190723',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp119.r1i1p1f1.Amon.pr.gr.20201123',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp119.r1i1p1f1.Amon.pr.gr.20201124',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp119.r1i1p1f1.Amon.ua.gr.20201123',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp119.r1i1p1f1.Amon.ua.gr.20201124',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp126.r1i1p1f1.Amon.pr.gr.20201123',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp126.r1i1p1f1.Amon.pr.gr.20201124',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp126.r1i1p1f1.Amon.ua.gr.20201123',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp126.r1i1p1f1.Amon.ua.gr.20201124',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp245.r1i1p1f1.Amon.pr.gr.20201125',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp245.r1i1p1f1.Amon.ua.gr.20201125',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp370.r1i1p1f1.Amon.pr.gr.20201125',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp370.r1i1p1f1.Amon.ua.gr.20201125',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp585.r1i1p1f1.Amon.pr.gr.20201123',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp585.r1i1p1f1.Amon.pr.gr.20201124',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp585.r1i1p1f1.Amon.ua.gr.20201123',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp585.r1i1p1f1.Amon.ua.gr.20201124',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Amon.pr.gr.20190606',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Amon.pr.gr.20190610',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Amon.ua.gr.20190606',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Amon.ua.gr.20190610',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp119.r1i1p1f1.Amon.pr.gr.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp119.r1i1p1f1.Amon.pr.gr.20190713',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp119.r1i1p1f1.Amon.pr.gr.20190714',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp119.r1i1p1f1.Amon.pr.gr.20190716',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp119.r1i1p1f1.Amon.pr.gr.20190717',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r1i1p1f1.Amon.pr.gr.20190628',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r1i1p1f1.Amon.ua.gr.20190628',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp370.r1i1p1f1.Amon.pr.gr.20190630',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp370.r1i1p1f1.Amon.ua.gr.20190630',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r1i1p1f1.Amon.pr.gr.20190630',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r1i1p1f1.Amon.ua.gr.20190630',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r1i1p1f1.Amon.pr.gr.20190710',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r1i1p1f1.Amon.ua.gr.20190710',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp119.r4i1p1f1.Amon.pr.gr.20190930',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp119.r4i1p1f1.Amon.pr.gr.20191007',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp119.r4i1p1f1.Amon.pr.gr.20191008',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp119.r4i1p1f1.Amon.ua.gr.20190930',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp119.r4i1p1f1.Amon.ua.gr.20191007',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp119.r4i1p1f1.Amon.ua.gr.20191008',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r1i1p1f1.Amon.pr.gr.20190630',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r1i1p1f1.Amon.ua.gr.20190630',
#  'CMIP6.ScenarioMIP.INM.INM-CM4-8.ssp126.r1i1p1f1.Amon.pr.gr1.20190601',
#  'CMIP6.ScenarioMIP.INM.INM-CM4-8.ssp245.r1i1p1f1.Amon.pr.gr1.20190601',
#  'CMIP6.ScenarioMIP.INM.INM-CM4-8.ssp370.r1i1p1f1.Amon.pr.gr1.20190531',
#  'CMIP6.ScenarioMIP.INM.INM-CM4-8.ssp585.r1i1p1f1.Amon.pr.gr1.20190531',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp126.r1i1p1f1.Amon.pr.gr1.20190618',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp126.r1i1p1f1.Amon.ua.gr1.20190618',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp245.r1i1p1f1.Amon.pr.gr1.20190618',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp245.r1i1p1f1.Amon.ua.gr1.20190618',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp370.r1i1p1f1.Amon.pr.gr1.20190617',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp370.r1i1p1f1.Amon.ua.gr1.20190617',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp585.r1i1p1f1.Amon.pr.gr1.20190723',
#  'CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp585.r1i1p1f1.Amon.ua.gr1.20190723',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp119.r1i1p1f1.Amon.pr.gr.20190322',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp119.r1i1p1f1.Amon.ua.gr.20190322',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp126.r1i1p1f1.Amon.pr.gr.20181218',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp126.r1i1p1f1.Amon.ua.gr.20181218',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245.r1i1p1f1.Amon.pr.gr.20181205',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245.r1i1p1f1.Amon.ua.gr.20181205',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp370.r1i1p1f1.Amon.pr.gr.20181218',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp370.r1i1p1f1.Amon.ua.gr.20181218',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Amon.pr.gr.20181218',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Amon.ua.gr.20181218',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.1pctCO2.r1i1p1f2.Omon.zostoga.gn.20190823',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.piControl.r1i1p1f2.Omon.zostoga.gn.20190823',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp119.r1i1p1f2.Amon.pr.gn.20190711',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp119.r1i1p1f2.Amon.ua.gn.20190711',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r1i1p1f2.Amon.pr.gn.20190712',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp126.r1i1p1f2.Amon.ua.gn.20190712',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp245.r1i1p1f2.Amon.pr.gn.20190713',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp245.r1i1p1f2.Amon.ua.gn.20190713',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp370.r1i1p1f2.Amon.pr.gn.20190715',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp370.r1i1p1f2.Amon.ua.gn.20190715',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r1i1p1f2.Amon.pr.gn.20190710',
#  'CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r1i1p1f2.Amon.ua.gn.20190710',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp119.r1i1p1f1.Amon.pr.gn.20190715',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp119.r1i1p1f1.Amon.ua.gn.20190715',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp126.r1i1p1f1.Amon.pr.gn.20190612',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp126.r1i1p1f1.Amon.ua.gn.20190612',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp245.r1i1p1f1.Amon.pr.gn.20190614',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp245.r1i1p1f1.Amon.ua.gn.20190614',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp370.r1i1p1f1.Amon.pr.gn.20190619',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp370.r1i1p1f1.Amon.ua.gn.20190619',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp585.r1i1p1f1.Amon.pr.gn.20190619',
#  'CMIP6.ScenarioMIP.MIROC.MIROC6.ssp585.r1i1p1f1.Amon.ua.gn.20190619',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp126.r1i1p1f3.Amon.pr.gn.20200113',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp126.r1i1p1f3.Amon.ua.gn.20200113',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp245.r1i1p1f3.Amon.pr.gn.20190906',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp245.r1i1p1f3.Amon.ua.gn.20190906',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp585.r1i1p1f3.Amon.pr.gn.20200113',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp585.r1i1p1f3.Amon.ua.gn.20200113',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-MM.ssp126.r1i1p1f3.Amon.pr.gn.20200512',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-MM.ssp126.r1i1p1f3.Amon.ua.gn.20200512',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-MM.ssp585.r1i1p1f3.Amon.pr.gn.20200505',
#  'CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-MM.ssp585.r1i1p1f3.Amon.ua.gn.20200505',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.1pctCO2.r1i1p1f2.Omon.zostoga.gm.20190406',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.piControl.r1i1p1f2.Omon.zostoga.gm.20200828',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp119.r1i1p1f2.Amon.pr.gn.20190827',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp119.r1i1p1f2.Amon.ua.gn.20190827',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r1i1p1f2.Amon.pr.gn.20190418',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r1i1p1f2.Amon.ua.gn.20190418',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245.r1i1p1f2.Amon.pr.gn.20190418',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245.r1i1p1f2.Amon.ua.gn.20190418',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp370.r1i1p1f2.Amon.pr.gn.20190418',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp370.r1i1p1f2.Amon.ua.gn.20190418',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r1i1p1f2.Amon.pr.gn.20190418',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r1i1p1f2.Amon.ua.gn.20190418',
#  'CMIP6.CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.r1i1p1f1.Amon.tas.gn.20190710',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp126.r1i1p1f1.Amon.pr.gn.20191025',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp126.r1i1p1f1.Amon.pr.gn.20191029',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp126.r1i1p1f1.Amon.ua.gn.20191025',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp126.r1i1p1f1.Amon.ua.gn.20191029',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp245.r1i1p1f1.Amon.pr.gn.20191105',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp245.r1i1p1f1.Amon.ua.gn.20191105',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp370.r1i1p1f1.Amon.pr.gn.20191104',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp370.r1i1p1f1.Amon.ua.gn.20191104',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r1i1p1f1.Amon.pr.gn.20191111',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r1i1p1f1.Amon.pr.gn.20191112',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r1i1p1f1.Amon.ua.gn.20191111',
#  'CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.r1i1p1f1.Amon.ua.gn.20191112',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp119.r1i1p1f1.Amon.pr.gn.20190220',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp119.r1i1p1f1.Amon.ua.gn.20190305',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp126.r1i1p1f1.Amon.pr.gn.20190220',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp126.r1i1p1f1.Amon.ua.gn.20190304',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp245.r1i1p1f1.Amon.pr.gn.20190220',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp245.r1i1p1f1.Amon.ua.gn.20190305',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp370.r1i1p1f1.Amon.pr.gn.20190220',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp370.r1i1p1f1.Amon.ua.gn.20190304',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r1i1p1f1.Amon.pr.gn.20190220',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r1i1p1f1.Amon.ua.gn.20190304',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp119.r1i1p1f2.Amon.pr.gn.20200422',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp119.r1i1p1f2.Amon.pr.gn.20200423',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp119.r1i1p1f2.Amon.ua.gn.20200422',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp119.r1i1p1f2.Amon.ua.gn.20200423',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp126.r1i1p1f2.Amon.pr.gn.20200207',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp126.r1i1p1f2.Amon.ua.gn.20200207',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp585.r1i1p1f2.Amon.pr.gn.20200208',
#  'CMIP6.ScenarioMIP.NASA-GISS.GISS-E2-1-G.ssp585.r1i1p1f2.Amon.ua.gn.20200208',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM.historical.r1i1p1f1.Amon.pr.gn.20190313',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp126.r1i1p1f1.Amon.pr.gn.20190313',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp126.r1i1p1f1.Amon.ua.gn.20190214',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp245.r1i1p1f1.Amon.pr.gn.20190331',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp245.r1i1p1f1.Amon.ua.gn.20190331',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp370.r1i1p1f1.Amon.pr.gn.20190330',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp370.r1i1p1f1.Amon.ua.gn.20190330',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Amon.pr.gn.20190313',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Amon.ua.gn.20190208',
#  'CMIP6.CMIP.NCAR.CESM2.1pctCO2.r1i1p1f1.Omon.zostoga.gn.20190425',
#  'CMIP6.CMIP.NCAR.CESM2.piControl.r1i1p1f1.Omon.zostoga.gn.20190320',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.pr.gn.20191123',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.pr.gn.20191202',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.pr.gn.20191206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.pr.gn.20191218',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.pr.gn.20191219',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.pr.gn.20191225',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.ua.gn.20191123',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.ua.gn.20191202',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.ua.gn.20191206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.ua.gn.20191218',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.ua.gn.20191219',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126.r1i1p1f1.Amon.ua.gn.20191225',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.pr.gn.20191206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.pr.gn.20191207',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.pr.gn.20191208',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.pr.gn.20191230',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.ua.gn.20191206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.ua.gn.20191207',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.ua.gn.20191208',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245.r1i1p1f1.Amon.ua.gn.20191230',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.pr.gn.20191208',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.pr.gn.20191209',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.pr.gn.20191213',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.pr.gn.20191214',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.pr.gn.20191231',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.pr.gn.20200117',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.ua.gn.20191208',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.ua.gn.20191209',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.ua.gn.20191213',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.ua.gn.20191214',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.ua.gn.20191231',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp370.r1i1p1f1.Amon.ua.gn.20200117',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp585.r1i1p1f1.Amon.pr.gn.20191219',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp585.r1i1p1f1.Amon.pr.gn.20191220',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp585.r1i1p1f1.Amon.pr.gn.20191221',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp585.r1i1p1f1.Amon.ua.gn.20191219',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp585.r1i1p1f1.Amon.ua.gn.20191220',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp585.r1i1p1f1.Amon.ua.gn.20191221',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.pr.gn.20191203',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.pr.gn.20191216',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.pr.gn.20191217',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.pr.gn.20191224',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.pr.gn.20191225',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.pr.gn.20191226',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.pr.gn.20191227',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.ua.gn.20191203',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.ua.gn.20191216',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.ua.gn.20191217',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.ua.gn.20191224',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.ua.gn.20191225',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.ua.gn.20191226',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126.r1i1p1f1.Amon.ua.gn.20191227',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.pr.gn.20191206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.pr.gn.20191231',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.pr.gn.20200204',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.pr.gn.20200205',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.pr.gn.20200206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.pr.gn.20200207',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.pr.gn.20200210',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.ua.gn.20191206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.ua.gn.20191231',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.ua.gn.20200204',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.ua.gn.20200205',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.ua.gn.20200206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.ua.gn.20200207',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245.r1i1p1f1.Amon.ua.gn.20200210',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.pr.gn.20200204',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.pr.gn.20200205',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.pr.gn.20200206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.pr.gn.20200207',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.pr.gn.20200208',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.ua.gn.20200204',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.ua.gn.20200205',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.ua.gn.20200206',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.ua.gn.20200207',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp370.r1i1p1f1.Amon.ua.gn.20200208',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.pr.gn.20200126',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.pr.gn.20200127',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.pr.gn.20200128',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.pr.gn.20200129',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.pr.gn.20200130',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.pr.gn.20200131',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.ua.gn.20200126',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.ua.gn.20200127',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.ua.gn.20200128',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.ua.gn.20200129',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.ua.gn.20200130',
#  'CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585.r1i1p1f1.Amon.ua.gn.20200131',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-CM4.historical.r1i1p1f1.Amon.pr.gr1.20190227',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-CM4.historical.r1i1p1f1.Amon.pr.gr1.20190228',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-CM4.historical.r1i1p1f1.Amon.ua.gr1.20190227',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-CM4.historical.r1i1p1f1.Amon.ua.gr1.20190228',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp245.r1i1p1f1.Amon.pr.gr1.20190317',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp245.r1i1p1f1.Amon.ua.gr1.20190317',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp585.r1i1p1f1.Amon.pr.gr1.20190318',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp585.r1i1p1f1.Amon.ua.gr1.20190318',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp119.r1i1p1f1.Amon.pr.gr1.20190619',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp119.r1i1p1f1.Amon.ua.gr1.20190619',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp126.r1i1p1f1.Amon.pr.gr1.20190618',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp126.r1i1p1f1.Amon.ua.gr1.20190618',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp245.r1i1p1f1.Amon.pr.gr1.20190617',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp245.r1i1p1f1.Amon.ua.gr1.20190617',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp370.r1i1p1f1.Amon.pr.gr1.20190618',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp370.r1i1p1f1.Amon.ua.gr1.20190618',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp585.r1i1p1f1.Amon.pr.gr1.20190618',
#  'CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp585.r1i1p1f1.Amon.ua.gr1.20190618',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp126.r1i1p1f2.Amon.pr.gn.20190504',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp126.r1i1p1f2.Amon.ua.gn.20190504',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp245.r1i1p1f2.Amon.pr.gn.20190504',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp245.r1i1p1f2.Amon.ua.gn.20190504',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp370.r1i1p1f2.Amon.pr.gn.20190504',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp370.r1i1p1f2.Amon.ua.gn.20190504',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp585.r1i1p1f2.Amon.pr.gn.20190504',
#  'CMIP6.ScenarioMIP.UA.MCM-UA-1-0.ssp585.r1i1p1f2.Amon.ua.gn.20190504',
#  'CMIP6.AerChemMIP.BCC.BCC-ESM1.ssp370.r1i1p1f1.Amon.tas.gn.20190314',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126.r1i1p1f1.Omon.ph.gn.',
#  'CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp370.r1i1p1f1.Omon.ph.gn.',
#  'CMIP6.CMIP.BCC.BCC-CSM2-MR.historical.r1i1p1f1.Omon.mlotst.gn.',
#  'CMIP6.CMIP.BCC.BCC-CSM2-MR.historical.r1i1p1f1.Omon.so.gn.',
#  'CMIP6.CMIP.BCC.BCC-CSM2-MR.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r1i1p1f1.Lmon.treeFrac.gn.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.o2.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.so.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.talk.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.dfe.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.po4.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.chl.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.dissic.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.thetao.gr1.',
#  'CMIP6.CMIP.MIROC.MIROC6.historical.r1i1p1f1.Omon.mlotst.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Lmon.mrro.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.chl.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.dfe.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.dissic.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.mlotst.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.no3.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.o2.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.so.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.talk.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r2i1p1f2.Omon.po4.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r2i1p1f2.Omon.si.gn.',
#  'CMIP6.AerChemMIP.NIMS-KMA.UKESM1-0-LL.ssp370-lowNTCF.r3i1p1f2.AERmon.o3.gn.20201023',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r1i1p1f2.AERmon.mmroa.gn.190503',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r1i1p1f2.AERmon.o3.gn.20190503',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r2i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r3i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r4i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126.r8i1p1f2.AERmon.o3.gn.20190510',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245.r1i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245.r2i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245.r3i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245.r4i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245.r8i1p1f2.AERmon.o3.gn.20190510',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r1i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r2i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r3i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.r4i1p1f2.AERmon.o3.gn.20190507',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r10i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r11i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r12i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r13i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r14i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r15i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r1i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r2i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r3i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r4i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r5i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r6i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r7i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r8i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.CCCma.CanESM5.historical.r9i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r1i1p1f1.Amon.pr.gr.20190925',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r10i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r1i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r2i1p1f1.Amon.pr.gn.20191018',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r3i1p1f1.Amon.pr.gn.20191018',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r4i1p1f1.Amon.pr.gn.20191018',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r5i1p1f1.Amon.pr.gn.20191018',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r6i1p1f1.Amon.pr.gn.20191018',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r7i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r8i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-GHG.r9i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r10i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r1i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r2i1p1f1.Amon.pr.gn.20191024',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r3i1p1f1.Amon.pr.gn.20191024',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r4i1p1f1.Amon.pr.gn.20191024',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r5i1p1f1.Amon.pr.gn.20191024',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r6i1p1f1.Amon.pr.gn.20191024',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r7i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r8i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-aer.r9i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r10i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r1i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r2i1p1f1.Amon.pr.gn.20191023',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r3i1p1f1.Amon.pr.gn.20191023',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r4i1p1f1.Amon.pr.gn.20191023',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r5i1p1f1.Amon.pr.gn.20191023',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r6i1p1f1.Amon.pr.gn.20191023',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r7i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r8i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.DAMIP.CCCma.CanESM5.hist-nat.r9i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.ScenarioMIP.CCCma.CanESM5.ssp126.r1i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.ScenarioMIP.CCCma.CanESM5.ssp245.r1i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.ScenarioMIP.CCCma.CanESM5.ssp585.r1i1p1f1.Amon.pr.gn.20190430',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r1i1p1f1.Amon.pr.gr.20190926',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r1i1p1f1.Amon.pr.gr.20190927',
#  'CMIP6.CMIP.AS-RCEC.TaiESM1.historical.r1i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.AWI.AWI-CM-1-1-MR.historical.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.CMIP.AWI.AWI-CM-1-1-MR.historical.r2i1p1f1.Amon.tas.gn.',
#  'CMIP6.CMIP.AWI.AWI-CM-1-1-MR.historical.r3i1p1f1.Amon.tas.gn.',
#  'CMIP6.CMIP.AWI.AWI-CM-1-1-MR.historical.r4i1p1f1.Amon.tas.gn.',
#  'CMIP6.CMIP.AWI.AWI-CM-1-1-MR.historical.r5i1p1f1.Amon.tas.gn.',
#  'CMIP6.CMIP.CAS.CAS-ESM2-0.historical.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.CMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.historical.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.CMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.historical.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.CMIP.CSIRO.ACCESS-ESM1-5.historical.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.CMIP.E3SM-Project.E3SM-1-0.historical.r2i1p1f1.SImon.siconc.gr.',
#  'CMIP6.CMIP.E3SM-Project.E3SM-1-0.historical.r3i1p1f1.SImon.siconc.gr.',
#  'CMIP6.CMIP.E3SM-Project.E3SM-1-0.historical.r5i1p1f1.SImon.siconc.gr.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Amon.tas.gr.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Omon.hfds.gn.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r1i1p1f1.Omon.wfo.gn.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r2i1p1f1.Amon.tas.gr.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r2i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r3i1p1f1.Amon.tas.gr.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r3i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r4i1p1f1.SImon.siconc.gn.20190702',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r7i1p1f1.Amon.tas.gr.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.r8i1p1f1.Amon.tas.gr.',
# ...
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r21i1p1f1.Amon.tas.gr.20190312',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r22i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r24i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r2i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r2i1p1f1.SImon.siconc.gn.20190729',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r3i1p1f1.Amon.tas.gr.20190510',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r4i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r7i1p1f1.Amon.tas.gr.20190302',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r7i1p1f1.SImon.siconc.gn.20190302',
#  'CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical.r7i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.CMIP.MOHC NERC.HadGEM3-GC31-LL.historical.r1i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC NERC.HadGEM3-GC31-LL.historical.r2i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC NERC.HadGEM3-GC31-LL.historical.r3i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC NERC.HadGEM3-GC31-LL.historical.r4i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-MM.historical.r1i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-MM.historical.r2i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-MM.historical.r3i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC.HadGEM3-GC31-MM.historical.r4i1p1f3.Amon.tas.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.hfds.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.tauuo.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.tos.gn.',
#  'CMIP6.CMIP.MOHC.UKESM1-0-LL.historical.r1i1p1f2.Omon.wfo.gn.',
#  'CMIP6.CMIP.NASA-GISS.GISS-E2-1-G.piControl.r1i1p1f1.Ofx.areacello.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM.historical.r1i1p1f1.Omon.hfds.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM.historical.r1i1p1f1.Omon.tauuo.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM.historical.r1i1p1f1.Omon.tauvo.gn.',
#  'CMIP6.CMIP.NCAR.CESM2-WACCM.historical.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r11i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r12i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r13i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r14i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r15i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r16i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r17i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r18i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r19i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r1i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r20i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r21i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r22i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r23i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r24i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r25i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r27i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r28i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r29i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r2i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r30i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r3i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r5i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r6i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r7i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r8i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NCC.NorCPM1.historical.r9i1p1f1.SImon.siconc.gn.',
#  'CMIP6.CMIP.NOAA-GFDL.GFDL-ESM4.historical.r1i1p1f1.SImon.siconc.gr.',
#  'CMIP6.CMIP.THU.CIESM.historical.r1i1p1f1.Omon.hfds.gn.',
#  'CMIP6.CMIP.THU.CIESM.historical.r1i1p1f1.Omon.tauuo.gn.',
#  'CMIP6.CMIP.THU.CIESM.historical.r1i1p1f1.Omon.tauvo.gn.',
#  'CMIP6.CMIP.THU.CIESM.historical.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.HighResMIP.MPI-M.MPI-ESM1-2-HR.hist-1950.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.HighResMIP.MPI-M.MPI-ESM1-2-XR.hist-1950.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp126.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.CAS.FGOALS-f3-L.ssp245.r1i1p1f1.Omon.thetao.gn.20191008',
#  'CMIP6.ScenarioMIP.CAS.FGOALS-f3-L.ssp370.r1i1p1f1.Omon.thetao.gn.20191008',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp126.r2i1p1f2.Omon.tos.gr1.20190410',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp245.r2i1p1f2.Omon.tos.gr1.20190410',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp370.r2i1p1f2.Omon.tos.gr1.20190410',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp585.r1i1p1f2.Omon.hfds.gn.',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp585.r1i1p1f2.Omon.wfo.gn.',
#  'CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp585.r2i1p1f2.Omon.tos.gr1.20190410',
#  'CMIP6.ScenarioMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.ssp126.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.ssp126.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.ssp245.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.ssp245.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.ssp585.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.CSIRO-ARCCSS-BoM.ACCESS-CM2.ssp585.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp126.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp245.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r1i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r1i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r2i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r3i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r4i1p1f1.SImon.siconc.gn.20190702',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r7i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r8i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126.r9i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r1i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r1i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r2i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r2i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r2i1p1f1.SImon.siconc.gn.20190702',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r3i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r4i1p1f1.SImon.siconc.gn.20190702',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r7i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r8i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245.r9i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r1i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r1i1p1f1.Omon.hfds.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r1i1p1f1.Omon.wfo.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r1i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r2i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r2i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r2i1p1f1.SImon.siconc.gn.20190702',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r3i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r4i1p1f1.SImon.siconc.gn.20190702',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r7i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r8i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585.r9i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r11i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r11i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r13i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r13i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r15i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r15i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r4i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r6i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r6i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r9i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.r9i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r11i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r11i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r12i1p1f1.SImon.siconc.gn.20190312',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r12i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r13i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r13i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r14i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r14i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r14i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r15i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r15i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r16i1p1f1.SImon.siconc.gn.20190312',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r16i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r17i1p1f1.SImon.siconc.gn.20190419',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r17i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r18i1p1f1.SImon.siconc.gn.20190315',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r18i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r21i1p1f1.SImon.siconc.gn.20190312',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r21i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r22i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r22i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r2i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r2i1p1f1.SImon.siconc.gn.20190729',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r4i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r6i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r6i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r9i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.r9i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r11i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r11i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r13i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r13i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r15i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r1i1p1f1.Omon.hfds.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r1i1p1f1.Omon.wfo.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r4i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r4i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r9i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.r9i1p1f1.SImon.siconc.gn.20190712',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp126.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp126.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245.r2i1p1f1.Amon.tas.gr.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245.r2i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245.r2i1p1f1.SImon.siareas.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245.r2i1p1f1.SImon.siconc.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Omon.hfds.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Omon.tauuo.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Omon.tauvo.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r1i1p1f1.Omon.wfo.gn.',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp126.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp585.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp126.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp245.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Omon.hfds.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Omon.tauuo.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Omon.tauvo.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Omon.thetao.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.Omon.tos.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585.r1i1p1f1.SImon.siarean.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2.ssp126.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2.ssp126.r2i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2.ssp245.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2.ssp245.r2i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2.ssp245.r3i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2.ssp585.r1i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.NCAR.CESM2.ssp585.r2i1p1f1.Amon.tas.gn.',
#  'CMIP6.ScenarioMIP.THU.CIESM.ssp126.r1i1p1f1.Omon.tos.gn.']

# %%
with open ("cmip6_list_data_ref_syntax_wrong-drs-by-pids.txt", 'w') as f:
    f.write("data_ref_syntax\n")
    for dset in drs_wrong :
        #f.write
        f.write('.'.join(dset.split('.')[1:])+"\n")

# %%
len(drs_wrong)
# Out:
# 860
